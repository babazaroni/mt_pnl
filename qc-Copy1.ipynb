# %%
#process the quantconnect notebook by sending a cell code, and reading response

from selenium import webdriver
from selenium.common.exceptions import NoSuchWindowException,WebDriverException,StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

import datetime as dt
from datetime import timedelta

import time as tm
import json
import pickle
import pprint
from mt_utils import mt_dict_to_df,mt_df_to_dict
from mt_data import options_cache,concat_dfs,add_underlying_cache,search_underlying_cache,add_options_cache
from mt_data import search_options_cache

# %%
def wait_for_element(func,id,tries):
    while True:
        try:
            form = func(id)
            return form
        
        except NoSuchElementException as e:
            tries -= 1
            if not tries:
                raise e
            tm.sleep(.1)


def manual_login(driver,qc_info):

    log_in = wait_for_element(driver.find_element_by_xpath,'//a[@href="/login"]',10)

    log_in.click()
    
    social_group = wait_for_element(driver.find_element_by_class_name,'btn-social-group',10)
    
    buttons = social_group.find_elements_by_class_name('btn')
    buttons[1].click()
    
    fb_login_form = wait_for_element(driver.find_element_by_id,'loginform',10)
    
    fb_email = fb_login_form.find_element_by_id('email')
    fb_email.send_keys(qc_info['email'])
    fb_pass = fb_login_form.find_element_by_id('pass')
    fb_pass.send_keys(qc_info['password'])
    fb_login = fb_login_form.find_element_by_id('loginbutton')
    fb_login.click()
    wait_for_element(driver.find_element_by_class_name,'start-here-section',10)
    return

def load_research_notebook(driver):
    while True:
        file_list = wait_for_element(driver.find_elements_by_class_name,"file-name",10)
        if not len(file_list):
            tm.sleep(.1)
        else:
            break
            
    for f in file_list:
        if f.text == 'research.ipynb':
            print("clicking",f.text)
            f.click()
            break
            
    notebook_frame = wait_for_element(driver.find_element_by_class_name,"notebook-frame",10)        
    driver.switch_to.frame(notebook_frame)
            
def load_project(driver,info):
    driver.get(info['url_project'])
    
def datetime_as_args(date):
    return '{},{},{},{},{}'.format(date.year,date.month,date.day,date.time().hour,date.time().minute)

def send_combo_keys(driver,key1,key2):
    actions = ActionChains(driver)
    actions.key_down(key1)
    actions.send_keys(key2)
    actions.key_up(key1)

def send_multiline_text(driver,element,text_lines):
    text_area = element.find_element_by_tag_name("textarea")
    for line in text_lines:
        send_combo_keys(driver,Keys.ALT,Keys.ARROW_LEFT) # go to beginning of line in case of auto indention
        text_area.send_keys(line+ Keys.ENTER)  #send text

class Error(Exception):
    pass

class QcResponseError(Error):
    pass

def get_cell(cell_num):
    cells = driver.find_elements_by_class_name("cell")

    cell = cells[cell_num]
    
    return cell


def get_code_mirror(cell):
    
    code_mirror = cell.find_element_by_class_name("CodeMirror")
    
    return code_mirror


def execute_cell(cell):
    
    get_code_mirror(cell).find_element_by_tag_name("textarea").send_keys(Keys.SHIFT + Keys.ENTER)   #execute cell with SHIFT_ENTER
    
def enter_cell(cell):
    
    code_mirror = get_code_mirror(cell)

    code_mirror.click()
    
    return code_mirror

 

def execute_cell_lines(cell,cell_lines):
    
    
    enter_cell(cell)
    
    code_mirror = get_code_mirror(cell)
    

    code_mirror.find_element_by_tag_name("textarea").send_keys(Keys.CONTROL + 'a')  #select all text in cell so it will be replaced
    send_multiline_text(driver,code_mirror,cell_lines)

    
    execute_cell(cell)
    

def get_cell_response(cell):
    
    output_subarea = wait_for_element(cell.find_element_by_class_name,"output_subarea",10000)  #read results
    
    return output_subarea.text

def get_parsed_cell_response(cell,tries = 100):

    while(tries):
        text = get_cell_response(cell)
        
        start_index = find_start_line_sequence(text,'[')
        if start_index != None:
            return text[start_index:]
        
        tm.sleep(.2)
        tries -= 1
        
    return None


def get_option(sym,start_time,end_time,spread_type,strike):
    time_format = "%Y,%m,%d,%H,%M"
    cell_lines = [
        "import datetime as dt",
        "#from mt_utils import get_option_data",
        "#from mt_utils import df_to_dict",
        "qb = QuantBook()",
        "df = get_option_data(qb,'{}',dt.datetime({}),dt.datetime({}),'{}',{},Resolution.Minute)".format(
            sym,
            datetime_as_args(start_time),
            datetime_as_args(end_time),
            spread_type,
            strike),
        "dct = df_to_dict(df)",
        "print(dct)"
    ]
    
    cell = get_cell(1)

    execute_cell_lines(cell,cell_lines)
    
    output_text = get_parsed_cell_response(cell)
    
    if output_text:
    
        results = eval(output_text)
    
        df = mt_dict_to_df(results)
    
        return df
    else:
        raise QcResponseError

def find_start_line_sequence(text,start_char):
    last_char = '\n'
    
    for i,c in enumerate(text):
        
        if last_char == '\n' and c == start_char:
            return i
        
        last_char = c
        
    return None
        
        
        
def get_history(symbol,start_time,end_time):
    time_format = "%Y,%m,%d,%H,%M"
    drop_string = "'askclose', 'askhigh', 'asklow', 'askopen', 'asksize', 'bidclose','bidhigh', 'bidlow', 'bidopen', 'bidsize', 'high', 'low','open', 'volume'"

    cell_lines = [
            "import datetime as dt",
            "#from mt_utils import df_to_dict",
            "qb = QuantBook()",
            "equity = qb.AddEquity('{}')".format(symbol),
            "start_time = dt.datetime({})".format(datetime_as_args(start_time)),
            "end_time = dt.datetime({})".format(datetime_as_args(end_time)),
            "history = qb.History(equity.Symbol, start_time, end_time, Resolution.Minute)",
            "history.reset_index(inplace = True)",
            "drop_list = [{}] if len(history) else [] ".format(drop_string),
            "history.drop(drop_list,axis=1,inplace = True)",
            "dct = df_to_dict(history)",
            "print(dct)"]
    
    cell = get_cell(1)

    execute_cell_lines(cell,cell_lines)
    
    output_text = get_parsed_cell_response(cell)
    
    if output_text:
    
        results = eval(output_text)
    
        df = mt_dict_to_df(results)
    
        return df
    else:
        raise QcResponseError
        
def get_option_bars(sym,start_time,end_time,strike_date,spread_type,strikes):
    
#    if sym == 'HES':
#        sym = 'AHC'
    
    
    for strike in strikes:
        
        df = search_options_cache(sym,strike_date,strike,spread_type,start_time,end_time)
        
        print("get_option_bars after search",sym,len(df))
        
        if len(df) == 0:
            print("downloading option",sym,spread_type,strike)
            
            df = get_option(sym,start_time,end_time,spread_type,strike)
                    
                
            if len(df):
                df['symbol'] = sym  #symbol return is not always symbol searched for
                add_options_cache(df)
        
def get_underlying_bars(sym,start_time,end_time):
        
    df = search_underlying_cache(event['sym'],ts,end_date)
        
    if len(df) == 0:
        print("downloading underlying")
        df = get_history(sym,ts,end_date)
        if len(df):
            df['symbol'] = sym  #symbol return is not always symbol searched for
            #df['symbol'] = [ sym.split()[0] for sym in df['symbol'] ]        
            add_underlying_cache(df)
        else:
            print("could not download:",sym)
    else:
        print("found in underlying_cache")

# %% [markdown]
# ## load project and notebook

# %%
QC_INFO_PATH = '/home/cc/QuantConnect/qc_info.json'

with open(QC_INFO_PATH,'r') as infile:
    qc_info = json.load(infile)

driver = webdriver.Chrome("/usr/local/bin/chromedriver")

driver.get(qc_info['url_main'])

manual_login(driver,qc_info)

# %%
load_project(driver,qc_info)

load_research_notebook(driver)
# Out:
# clicking research.ipynb

# %% [markdown]
# # Load data

# %%
from mt_data import download,data_global_set,data_init,data_info
from mt_data import get_holidays
import json
import datetime as dt
from datetime import timedelta




data_global_set(*data_init())

data_info()

actions = json.loads(download("https://www.dropbox.com/s/psgut932tw77b82/actions.json?dl=1"))
print(actions[0])

print("holidays = ",get_holidays())
# Out:
# download_data: https://www.dropbox.com/s/1lszx4xveis9x5i/qc_option_bars_100.json?dl=1
# download_data dict data:  28
# Download data df len: 137477
# prepare_options_cache Index(['symbol', 'time', 'type', 'expiry', 'strike', 'mid'], dtype='object')
# sorting options_cache
# finished
# after drop 137477
# data_init
# options_cache
#        symbol                time  type      expiry  strike    mid
# 1472     AAPL 2020-05-26 10:59:00   Put  2020-05-29   310.0  0.540
# 1473     AAPL 2020-05-26 11:00:00   Put  2020-05-29   310.0  0.545
# 1474     AAPL 2020-05-26 11:01:00   Put  2020-05-29   310.0  0.530
# 1475     AAPL 2020-05-26 11:02:00   Put  2020-05-29   310.0  0.520
# 1476     AAPL 2020-05-26 11:03:00   Put  2020-05-29   310.0  0.500
# ...       ...                 ...   ...         ...     ...    ...
# 137472     ZM 2020-06-05 15:56:00  Call  2020-06-05   235.0  0.050
# 137473     ZM 2020-06-05 15:57:00  Call  2020-06-05   235.0  0.050
# 137474     ZM 2020-06-05 15:58:00  Call  2020-06-05   235.0  0.050
# 137475     ZM 2020-06-05 15:59:00  Call  2020-06-05   235.0  0.050
# 137476     ZM 2020-06-05 16:00:00  Call  2020-06-05   235.0  0.050
#
# [137477 rows x 6 columns]
# Download data df len: 0
# data_global_set        symbol                time  type      expiry  strike    mid
# 1472     AAPL 2020-05-26 10:59:00   Put  2020-05-29   310.0  0.540
# 1473     AAPL 2020-05-26 11:00:00   Put  2020-05-29   310.0  0.545
# 1474     AAPL 2020-05-26 11:01:00   Put  2020-05-29   310.0  0.530
# 1475     AAPL 2020-05-26 11:02:00   Put  2020-05-29   310.0  0.520
# 1476     AAPL 2020-05-26 11:03:00   Put  2020-05-29   310.0  0.500
# ...       ...                 ...   ...         ...     ...    ...
# 137472     ZM 2020-06-05 15:56:00  Call  2020-06-05   235.0  0.050
# 137473     ZM 2020-06-05 15:57:00  Call  2020-06-05   235.0  0.050
# 137474     ZM 2020-06-05 15:58:00  Call  2020-06-05   235.0  0.050
# 137475     ZM 2020-06-05 15:59:00  Call  2020-06-05   235.0  0.050
# 137476     ZM 2020-06-05 16:00:00  Call  2020-06-05   235.0  0.050
#
# [137477 rows x 6 columns] Empty DataFrame
# Columns: []
# Index: []
# 137477 0
# {'ts': '2020-05-26T06:52:24', 'action': 'shorting', 'sym': 'ZM', 'spread_type': 'CALL', 'strike_date': '2020-05-29', 'strikes': [180.0, 185.0]}
# holidays =  []

# %% [markdown]
# # Process Events

# %%
from mt_data import get_holidays

print("holidays")
print(get_holidays())

HOURS_TO_EST = 3

EVENT_LIMIT = 125

def process_events():

    for i,event in enumerate(actions):
    
        if i > EVENT_LIMIT:
            break
    
    
        if all(item in event.keys() for item in  ['action','sym','spread_type','strike_date','strikes']):
        
            if event['action'] != 'shorting':
                continue
            
#        if event['sym'] != "HES":
#            continue

            ts = dt.datetime.strptime(event['ts'], '%Y-%m-%dT%H:%M:%S') + timedelta(hours=HOURS_TO_EST)

            
            print(i,event['sym'],ts,event['strike_date'])
            if event['sym'] == 'SPX':
                print("don't bother downloading SPX, it's not there")
                continue
        
        
            end_date = dt.datetime.strptime(event['strike_date'],'%Y-%m-%d')
            end_time = end_date.replace(hour = 16,minute = 0)
        
#        get_underlying_bars(event['sym'],ts,end_time)
        
            get_option_bars(event['sym'],ts,end_time,end_time.date(),event['spread_type'],event['strikes'])
        
        
            
        
            
print("finished")
# Out:
# holidays
# []
# finished

# %%
keep_trying = True

while keep_trying:
    try:
        cell = get_cell(0)
        enter_cell(cell)
        execute_cell(cell)
        tm.sleep(2)
        process_events()
        keep_trying = False
    except:
        print("QcResponse error, trying again in 5 minutes",dt.datetime.now())
        tm.sleep(5*60)
# Out:
# 0 ZM 2020-05-26 09:52:24 2020-05-29
# search_options_cache found ZM 1538
# missing_data_by_date found all days
# get_option_bars after search ZM 1538
# search_options_cache found ZM 1538
# missing_data_by_date found all days
# get_option_bars after search ZM 1538
# 1 PYPL 2020-05-26 10:33:38 2020-06-05
# search_options_cache found PYPL 3447
# missing_data_by_date found all days
# get_option_bars after search PYPL 3447
# search_options_cache found PYPL 3447
# missing_data_by_date found all days
# get_option_bars after search PYPL 3447
# 2 HES 2020-05-26 10:41:19 2020-05-29
# search_options_cache found HES 0
# ======================= could not find date  2020-05-26 []
# get_option_bars after search HES 0
# downloading option HES PUT 46.0
# search_options_cache found HES 0
# ======================= could not find date  2020-05-26 []
# get_option_bars after search HES 0
# downloading option HES PUT 44.0
# 3 AAPL 2020-05-26 10:58:17 2020-05-29
# search_options_cache found AAPL 1472
# missing_data_by_date found all days
# get_option_bars after search AAPL 1472
# search_options_cache found AAPL 1472
# missing_data_by_date found all days
# get_option_bars after search AAPL 1472
# 4 GS 2020-05-26 14:59:16 2020-05-29
# search_options_cache found GS 1231
# missing_data_by_date found all days
# get_option_bars after search GS 1231
# search_options_cache found GS 1231
# missing_data_by_date found all days
# get_option_bars after search GS 1231
# 6 W 2020-05-26 15:47:03 2020-05-29
# search_options_cache found W 1183
# missing_data_by_date found all days
# get_option_bars after search W 1183
# search_options_cache found W 1183
# missing_data_by_date found all days
# get_option_bars after search W 1183
# 10 AMD 2020-05-27 09:47:18 2020-06-05
# search_options_cache found AMD 3103
# missing_data_by_date found all days
# get_option_bars after search AMD 3103
# search_options_cache found AMD 3103
# missing_data_by_date found all days
# get_option_bars after search AMD 3103
# 13 SPX 2020-05-27 10:52:12 2020-05-27
# don't bother downloading SPX, it's not there
# 14 SPX 2020-05-27 11:08:17 2020-05-27
# don't bother downloading SPX, it's not there
# 15 HES 2020-05-28 08:14:42 2020-06-05
# search_options_cache found HES 0
# ======================= could not find date  2020-05-28 []
# get_option_bars after search HES 0
# downloading option HES PUT 46.0
# search_options_cache found HES 0
# ======================= could not find date  2020-05-28 []
# get_option_bars after search HES 0
# downloading option HES PUT 41.0
# 16 MAR 2020-05-28 08:57:49 2020-06-05
# search_options_cache found MAR 2730
# missing_data_by_date found all days
# get_option_bars after search MAR 2730
# search_options_cache found MAR 2730
# missing_data_by_date found all days
# get_option_bars after search MAR 2730
# 17 BA 2020-05-28 10:07:58 2020-06-05
# search_options_cache found BA 2693
# missing_data_by_date found all days
# get_option_bars after search BA 2693
# search_options_cache found BA 2693
# missing_data_by_date found all days
# get_option_bars after search BA 2693
# 19 DKNG 2020-05-29 08:13:30 2020-06-05
# search_options_cache found DKNG 2340
# missing_data_by_date found all days
# get_option_bars after search DKNG 2340
# search_options_cache found DKNG 2340
# missing_data_by_date found all days
# get_option_bars after search DKNG 2340
# 20 COST 2020-05-29 10:12:18 2020-06-05
# search_options_cache found COST 2298
# missing_data_by_date found all days
# get_option_bars after search COST 2298
# search_options_cache found COST 2298
# missing_data_by_date found all days
# get_option_bars after search COST 2298
# 24 SBUX 2020-05-29 10:59:13 2020-06-05
# search_options_cache found SBUX 2251
# missing_data_by_date found all days
# get_option_bars after search SBUX 2251
# search_options_cache found SBUX 2251
# missing_data_by_date found all days
# get_option_bars after search SBUX 2251
# 25 DKNG 2020-05-29 11:01:14 2020-06-05
# search_options_cache found DKNG 2249
# missing_data_by_date found all days
# get_option_bars after search DKNG 2249
# search_options_cache found DKNG 2249
# missing_data_by_date found all days
# get_option_bars after search DKNG 2249
# 26 SPY 2020-05-29 11:20:26 2020-05-29
# search_options_cache found SPY 280
# missing_data_by_date found all days
# get_option_bars after search SPY 280
# search_options_cache found SPY 280
# missing_data_by_date found all days
# get_option_bars after search SPY 280
# 28 EA 2020-06-01 11:00:24 2020-06-05
# search_options_cache found EA 1860
# missing_data_by_date found all days
# get_option_bars after search EA 1860
# search_options_cache found EA 1860
# missing_data_by_date found all days
# get_option_bars after search EA 1860
# 29 NFLX 2020-06-01 11:03:20 2020-06-05
# search_options_cache found NFLX 1857
# missing_data_by_date found all days
# get_option_bars after search NFLX 1857
# search_options_cache found NFLX 1857
# missing_data_by_date found all days
# get_option_bars after search NFLX 1857
# 30 RCL 2020-06-01 15:28:46 2020-06-05
# search_options_cache found RCL 1592
# missing_data_by_date found all days
# get_option_bars after search RCL 1592
# search_options_cache found RCL 1592
# missing_data_by_date found all days
# get_option_bars after search RCL 1592
# 31 TSLA 2020-06-01 15:31:46 2020-06-05
# search_options_cache found TSLA 1589
# missing_data_by_date found all days
# get_option_bars after search TSLA 1589
# search_options_cache found TSLA 1589
# missing_data_by_date found all days
# get_option_bars after search TSLA 1589
# 32 DKNG 2020-06-02 07:58:41 2020-06-05
# search_options_cache found DKNG 1560
# missing_data_by_date found all days
# get_option_bars after search DKNG 1560
# search_options_cache found DKNG 0
# ======================= could not find date  2020-06-02 []
# get_option_bars after search DKNG 0
# downloading option DKNG CALL 537.0
# 34 BYND 2020-06-02 09:59:43 2020-06-05
# search_options_cache found BYND 1531
# missing_data_by_date found all days
# get_option_bars after search BYND 1531
# search_options_cache found BYND 1531
# missing_data_by_date found all days
# get_option_bars after search BYND 1531
# 35 SMH 2020-06-02 10:03:59 2020-06-05
# search_options_cache found SMH 1527
# missing_data_by_date found all days
# get_option_bars after search SMH 1527
# search_options_cache found SMH 1527
# missing_data_by_date found all days
# get_option_bars after search SMH 1527
# 38 DKNG 2020-06-02 11:13:05 2020-06-05
# search_options_cache found DKNG 1457
# missing_data_by_date found all days
# get_option_bars after search DKNG 1457
# search_options_cache found DKNG 1457
# missing_data_by_date found all days
# get_option_bars after search DKNG 1457
# 46 ZM 2020-06-03 09:39:38 2020-06-05
# search_options_cache found ZM 1161
# missing_data_by_date found all days
# get_option_bars after search ZM 1161
# search_options_cache found ZM 1161
# missing_data_by_date found all days
# get_option_bars after search ZM 1161
# 47 DAL 2020-06-03 09:53:30 2020-06-12
# search_options_cache found DAL 3097
# missing_data_by_date found all days
# get_option_bars after search DAL 3097
# search_options_cache found DAL 3097
# missing_data_by_date found all days
# get_option_bars after search DAL 3097
# 50 WYNN 2020-06-03 10:25:55 2020-06-12
# search_options_cache found WYNN 3065
# missing_data_by_date found all days
# get_option_bars after search WYNN 3065
# search_options_cache found WYNN 3065
# missing_data_by_date found all days
# get_option_bars after search WYNN 3065
# 51 LYFT 2020-06-03 10:33:38 2020-06-12
# search_options_cache found LYFT 3057
# missing_data_by_date found all days
# get_option_bars after search LYFT 3057
# search_options_cache found LYFT 3057
# missing_data_by_date found all days
# get_option_bars after search LYFT 3057
# 55 UAL 2020-06-03 15:48:01 2020-06-12
# search_options_cache found UAL 2742
# missing_data_by_date found all days
# get_option_bars after search UAL 2742
# search_options_cache found UAL 2742
# missing_data_by_date found all days
# get_option_bars after search UAL 2742
# 62 MU 2020-06-04 10:16:39 2020-06-12
# search_options_cache found MU 2684
# missing_data_by_date found all days
# get_option_bars after search MU 2684
# search_options_cache found MU 2684
# missing_data_by_date found all days
# get_option_bars after search MU 2684
# 68 ZM 2020-06-04 10:48:23 2020-06-05
# search_options_cache found ZM 702
# missing_data_by_date found all days
# get_option_bars after search ZM 702
# search_options_cache found ZM 702
# missing_data_by_date found all days
# get_option_bars after search ZM 702
# 72 RAD 2020-06-04 14:45:13 2020-06-12
# search_options_cache found RAD 2415
# missing_data_by_date found all days
# get_option_bars after search RAD 2415
# search_options_cache found RAD 2426
# missing_data_by_date found all days
# get_option_bars after search RAD 2426
# 73 BA 2020-06-04 15:10:20 2020-06-05
# search_options_cache found BA 440
# missing_data_by_date found all days
# get_option_bars after search BA 440
# search_options_cache found BA 440
# missing_data_by_date found all days
# get_option_bars after search BA 440
# 74 WMT 2020-06-04 15:24:55 2020-06-12
# search_options_cache found WMT 2376
# missing_data_by_date found all days
# get_option_bars after search WMT 2376
# search_options_cache found WMT 2376
# missing_data_by_date found all days
# get_option_bars after search WMT 2376
# 75 SPY 2020-06-04 15:54:27 2020-06-05
# search_options_cache found SPY 396
# missing_data_by_date found all days
# get_option_bars after search SPY 396
# search_options_cache found SPY 396
# missing_data_by_date found all days
# get_option_bars after search SPY 396
# 76 AMD 2020-06-04 19:21:24 2020-06-12
# search_options_cache found AMD 2340
# =================== missing_data_by_date skipping first day
# missing_data_by_date found all days
# get_option_bars after search AMD 2340
# search_options_cache found AMD 2340
# =================== missing_data_by_date skipping first day
# missing_data_by_date found all days
# get_option_bars after search AMD 2340
# 83 GRUB 2020-06-05 09:52:44 2020-06-12
# search_options_cache found GRUB 2318
# missing_data_by_date found all days
# get_option_bars after search GRUB 2318
# search_options_cache found GRUB 2318
# missing_data_by_date found all days
# get_option_bars after search GRUB 2318
# 86 RAD 2020-06-05 15:14:42 2020-06-12
# search_options_cache found RAD 1996
# missing_data_by_date found all days
# get_option_bars after search RAD 1996
# search_options_cache found RAD 2007
# missing_data_by_date found all days
# get_option_bars after search RAD 2007
# 92 SPY 2020-06-08 10:08:54 2020-06-08
# search_options_cache found SPY 352
# missing_data_by_date found all days
# get_option_bars after search SPY 352
# search_options_cache found SPY 352
# missing_data_by_date found all days
# get_option_bars after search SPY 352
# 96 AMZN 2020-06-08 14:54:40 2020-06-12
# search_options_cache found AMZN 1626
# missing_data_by_date found all days
# get_option_bars after search AMZN 1626
# search_options_cache found AMZN 1626
# missing_data_by_date found all days
# get_option_bars after search AMZN 1626
# 97 AAPL 2020-06-09 07:44:16 2020-06-12
# search_options_cache found AAPL 1560
# missing_data_by_date found all days
# get_option_bars after search AAPL 1560
# search_options_cache found AAPL 1560
# missing_data_by_date found all days
# get_option_bars after search AAPL 1560
# 100 GOOGL 2020-06-09 09:37:57 2020-06-12
# search_options_cache found GOOGL 1553
# missing_data_by_date found all days
# get_option_bars after search GOOGL 1553
# search_options_cache found GOOGL 1553
# missing_data_by_date found all days
# get_option_bars after search GOOGL 1553
# 105 NVDA 2020-06-09 10:59:11 2020-06-12
# search_options_cache found NVDA 0
# ======================= could not find date  2020-06-09 []
# get_option_bars after search NVDA 0
# downloading option NVDA PUT 345.0
# add_options_cache 1471 138948
# search_options_cache found NVDA 0
# ======================= could not find date  2020-06-09 []
# get_option_bars after search NVDA 0
# downloading option NVDA PUT 335.0
# add_options_cache 1471 140419
# 116 W 2020-06-10 14:19:57 2020-06-12
# search_options_cache found W 0
# ======================= could not find date  2020-06-10 []
# get_option_bars after search W 0
# downloading option W PUT 170.0
# add_options_cache 881 141300
# search_options_cache found W 0
# ======================= could not find date  2020-06-10 []
# get_option_bars after search W 0
# downloading option W PUT 165.0
# add_options_cache 881 142181
# 121 MA 2020-06-11 10:38:30 2020-06-19
# search_options_cache found MA 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search MA 0
# downloading option MA CALL 320.0
# add_options_cache 2662 144843
# search_options_cache found MA 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search MA 0
# downloading option MA CALL 330.0
# add_options_cache 2662 147505
# 122 FB 2020-06-11 11:01:03 2020-06-19
# search_options_cache found FB 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search FB 0
# downloading option FB CALL 242.5
# add_options_cache 2639 150144
# search_options_cache found FB 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search FB 0
# downloading option FB CALL 250.0
# add_options_cache 2639 152783
# 123 MKC 2020-06-11 11:15:04 2020-06-19
# search_options_cache found MKC 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search MKC 0
# downloading option MKC CALL 175.0
# add_options_cache 2625 155408
# search_options_cache found MKC 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search MKC 0
# downloading option MKC CALL 180.0
# add_options_cache 2625 158033
# 124 GOOGL 2020-06-11 14:14:30 2020-06-12
# search_options_cache found GOOGL 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search GOOGL 0
# downloading option GOOGL CALL 1460.0
# add_options_cache 496 158529
# search_options_cache found GOOGL 0
# ======================= could not find date  2020-06-11 []
# get_option_bars after search GOOGL 0
# downloading option GOOGL CALL 1470.0
# add_options_cache 496 159025

# %%
cell = get_cell(0)
enter_cell(cell)
execute_cell(cell)

# %%
execute_cell(0)

# %%
get_cell(0)

# %%
len(underlying_cache)

# %% [raw]
# print(underlying_cache)

# %%
underlying_cache

# %%
ar = ['aa b','b c']
[a.split()[0] for a in ar]

# %%
underlying_cache

# %%
import pandas as pd
date = dt.datetime(2020,9,7)
len(pd.bdate_range(date,date))

# %%
from mt_data import get_underlying_cache
from datetime import datetime
from datetime import date

from pandas.tseries.holiday import USFederalHolidayCalendar
import pprint

underlying_cache = get_underlying_cache()
pprint.pprint(underlying_cache)

print("len(underlying_cache):",len(underlying_cache))
    
pprint.pprint(underlying_cache)

cal = USFederalHolidayCalendar()
holidays = []

def find_holidays(df):
    global holidays
    
    holidays = [d.date() for d in cal.holidays(start = df['time'][0], end= date.today())]
    
    
find_holidays(underlying_cache)

print(holidays)

# %%
import datetime as datetime
after_hours_start = datetime.time(16,31,0)

# %%
from mt_data import get_underlying_cache
underlying_cache = get_underlying_cache()

# %%
text = 'abcdefg'
text[1:]

# %%
from mt_data import save_underlying_cache

save_underlying_cache('/home/cc/Dropbox/qc_underlying.json')

# %%
from mt_data import save_options_cache


save_options_cache('/home/cc/Dropbox/qc_option_bars_125.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d1ebbe69129c> in <module>
#       2
#       3
# ----> 4 save_options_cache('/home/cc/Dropbox/qc_option_bars_125.json')
#
# ~/options/process/python/MasterTrader/mt_data.py in save_options_cache(file_path)
#     273
#     274     with open(file_path,'w') as outfile:
# --> 275         json.dump(options_cache_dict,outfile)
#     276
#     277
#
# ~/anaconda3/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     427             yield _floatstr(o)
#     428         elif isinstance(o, (list, tuple)):
# --> 429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
#     431             yield from _iterencode_dict(o, _current_indent_level)
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~/anaconda3/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type date is not JSON serializable

# %%
set(list(options_cache['symbol']))

# %%
options_cache['symbol']

# %% [markdown]
# ### symbols that convert after get_history

# %% [markdown]
# HES to AHC

# %%
from mt_data import get_options_cache
df = get_options_cache()

# %%
print(df)

# %%
dt.date

# %%
dt.datetime.now()
